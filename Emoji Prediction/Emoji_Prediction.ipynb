# %% [markdown]
# Link - https://levelup.gitconnected.com/predicting-emojis-with-the-help-of-openai-331a3a91f27b

# %%
# install these dependencies
# !pip install torch transformers pillow
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 46.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 82.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 20.4 MB/s eta 0:00:00
# ...

# %%
# !gdown 19E7Agfm86iT44ViSnTjGpiOAGFldK4pj
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=19E7Agfm86iT44ViSnTjGpiOAGFldK4pj
# To: /content/emojis.zip
# 100% 31.6k/31.6k [00:00<00:00, 24.4MB/s]

# %%
# !unzip emojis.zip
# Out:
# Archive:  emojis.zip
#    creating: emojis/
#   inflating: emojis/8.png
#   inflating: emojis/9.png
#   inflating: emojis/14.png
#   inflating: emojis/28.png
#   inflating: emojis/29.png
#   inflating: emojis/15.png
#   inflating: emojis/17.png
#   inflating: emojis/16.png
#   inflating: emojis/12.png
#   inflating: emojis/13.png
#   inflating: emojis/11.png
#   inflating: emojis/10.png
#   inflating: emojis/21.png
#   inflating: emojis/20.png
#   inflating: emojis/22.png
#   inflating: emojis/23.png
#   inflating: emojis/27.png
#   inflating: emojis/26.png
#   inflating: emojis/18.png
#   inflating: emojis/30.png
#   inflating: emojis/24.png
#   inflating: emojis/25.png
#   inflating: emojis/31.png
#   inflating: emojis/19.png
#   inflating: emojis/4.png
#   inflating: emojis/5.png
#   inflating: emojis/7.png
#   inflating: emojis/6.png
#   inflating: emojis/2.png
#   inflating: emojis/3.png
#   inflating: emojis/1.png
#   inflating: emojis/0.png

# %%
# import the dependencies
from PIL import Image
from transformers import CLIPProcessor, CLIPModel
import torch

# emoji images: https://public-assets-vincent-claes.s3.eu-west-1.amazonaws.com/emoji-precitor/emojis.zip
path_to_emoji_folder = "emojis"
# read images
emojis_as_images = [Image.open(f"{path_to_emoji_folder}/{i}.png") for i in range(31)]

# load model and processor
checkpoint = "openai/clip-vit-base-patch32"
model = CLIPModel.from_pretrained(checkpoint)
processor = CLIPProcessor.from_pretrained(checkpoint)

# %% [markdown]
# Requirements.txt https://drive.google.com/file/d/1IreKy_x-jZJK4x6Lk9ikYLqyQRKUoSt7/view?usp=sharing

# %%
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 15.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 80.6/80.6 kB 8.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 594.4/594.4 kB 36.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.5/162.5 kB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 296.3/296.3 kB 22.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.2/4.2 MB 61.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.3/55.3 kB 5.6 MB/s eta 0:00:00
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 959.8/959.8 kB 44.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 158.8/158.8 kB 15.1 MB/s eta 0:00:00
# ...

# %%
import csv
import cv2
from google.colab.patches import cv2_imshow
from PIL import Image
import numpy as np

file = open('inputs.csv')
type(file)
csvreader = csv.reader(file)
rows = []

for rows in csvreader:
  text = rows[0] + " " + rows[3]
  text2 = rows[2] + ". " + rows[3]
  inputs = processor(text=text, images=emojis_as_images, return_tensors="pt", padding=True, truncation=True)
  outputs = model(**inputs)
  logits_per_text = outputs.logits_per_text
  prob = logits_per_text.softmax(dim=1)
  label = torch.argmax(prob).item()

  with open("outputs.csv", mode="a") as file2:
    writer = csv.writer(file2, delimiter=",")
    writer.writerow([rows[0], text2, label])
# Out:
# /usr/local/lib/python3.9/dist-packages/PIL/Image.py:975: UserWarning: Palette images with Transparency expressed in bytes should be converted to RGBA images
#   if str(e) == "cannot allocate more than 256 colors":
